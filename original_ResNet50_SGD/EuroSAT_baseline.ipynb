# %% [markdown]
# # Earth Observation - Land Classification on EuroSAT dataset
#
# * EuroSAT is a large-scale land use and land cover classification dataset derived from multispectral Sentinel-2 satellite imagery covering European continent.
#
# * EuroSAT is composed of 27,000 georeferenced image patches (64 x 64 pixels) - each patch comprises 13 spectral bands (optical through to shortwave infrared ) resampled to 10m spatila resolution and labelled with one of 10 distinct land cover classes: AnnualCrop, Forest, HerbaceousVegetation, Highway, Industrial, Pasture, PermanentCrop, Residential, River, SeaLake.
#
# * Full details including links to journal papers and download instructions may be found here: https://github.com/phelber/eurosat.
#
# ![alt text](https://github.com/phelber/EuroSAT/blob/master/eurosat_overview_small.jpg?raw=true)

# %% [markdown]
# ##  1. Setup Notebook Environment

# %% [markdown]
# ### 1.1 Import all required packages.

# %%
import ssl
import torch
import random
import numpy as np
import torch.nn as nn
from datetime import datetime
import matplotlib.pyplot as plt
from torchvision import models, transforms
from torchvision.datasets import EuroSAT
from torch.utils.tensorboard.writer import SummaryWriter
from torch.optim.lr_scheduler import MultiStepLR, CosineAnnealingWarmRestarts

# %% [markdown]
# ### 1.2 Configure settings for the corresponding optimizers and schedulers.

# %%
use_AdamW = False # Flag utilized for switching between AdamW and SGD optimizer.

if use_AdamW:
  config = {'train_test_split':0.1, # train test split ratio
            'tr_val_split':0.2, # train validation split ratio
            'seed':42, # random seed
            'mini_batch_size':128,
            'epochs':20,
            
            # Settings for the optimizer AdamW
            'lr':1e-3, # learning rate
            'weight_decay':5e-4,

            # Settings for the lr_scheduler CosineAnnealingWarmRestarts
            't_0':5, # Number of iterations for the first restart.
            'eta_min':1e-5, # Minimum learning rate
          }
else:
  config = {'train_test_split':0.1, # train test split ratio
            'tr_val_split':0.2, # train validation split ratio
            'seed':42, # random seed
            'mini_batch_size':128,
            'epochs':100,

            # Settings for the optimizer SGD
            'lr':1e-4, # learning rate
            'weight_decay':5e-4,  
            'momentum':0.9,

            # Settings for the lr_scheduler MultiStepLR
            'milestones':[50,75,90], # List of epoch indices.
            'gamma':0.2, # Multiplicative factor of learning rate decay.
          }

# %% [markdown]
# ### 1.3 Define a function to set a random seed for reproducibility assurance:
# * Manage sources of randomness that may lead to varying behaviors in multiple executions of your application.

# %%
def set_random_seed(seed=42):
    random.seed(seed) # set python seed
    np.random.seed(seed) # seed the global NumPy random number generator(RNG)
    torch.manual_seed(seed) # seed the RNG for all devices(both CPU and CUDA) 

set_random_seed(seed=config['seed'])

# %% [markdown]
# ### 1.4 Tracks the active GPU and allocates all new CUDA tensors on that device by default.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device = torch.device(device)

# %% [markdown]
# ## 2. Data Preparation:

# %% [markdown]
# ### 2.1 Preparing the dataset:

# %%
# Transform pipeline
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])])

# Dataset download
ssl._create_default_https_context = ssl._create_unverified_context # Turn off the ssl verification.
dataset_path = "../"
dataset = EuroSAT(root=dataset_path, transform=transform, download=True)

# Train/Test split
n = int(len(dataset) * (1 - config['train_test_split']))
eurosat_train, eurosat_test = torch.utils.data.random_split(dataset, [n, len(dataset) - n])

# %% [markdown]
# ### 2.2 Visualize Training Data

# %%
# Randomly select an image from the Training Data for visualization and print its corresponding label.
classes = ['AnnualCrop', 'Forest', 'HerbaceousVegetation', 'Highway', 'Industrial', 'Pasture', 'PermanentCrop', 'Residential', 'River', 'SeaLake']
random_index = random.randrange(len(eurosat_train)) # random select an index
random_image = eurosat_train[random_index][0].numpy().transpose((1, 2, 0))
mean = np.array([0.485, 0.456, 0.406])
std = np.array([0.229, 0.224, 0.225])
random_image = std * random_image + mean
random_image = np.clip(random_image, 0, 1)
print("Image", random_index, "'s label :", eurosat_train[random_index][1], classes[eurosat_train[random_index][1]])
plt.imshow(random_image)
# Out:
# Image 20952 's label : 6 PermanentCrop

# %% [markdown]
# ### 2.3 Instantiate PyTorch data loader that feeds the image tensors to our neural network

# %%
# Tr/Val split
n = int(len(eurosat_train) * config['tr_val_split'])
eurosat_tr, eurosat_val = torch.utils.data.random_split(eurosat_train, [n, len(eurosat_train) - n])

# instantiate data loaders
train_dataloader = torch.utils.data.DataLoader(eurosat_tr, batch_size=config['mini_batch_size'], shuffle=True)
val_dataloader = torch.utils.data.DataLoader(eurosat_val, batch_size=config['mini_batch_size'], shuffle=True)
test_dataloader = torch.utils.data.DataLoader(eurosat_test, batch_size=config['mini_batch_size'], shuffle=True)

# %% [markdown]
# ## 3. Model Training

# %% [markdown]
# ### 3.1 Create a ResNet-50 model using torchvision
#
# ResNet-50 from  Deep Residual Learning for Image Recognition(https://arxiv.org/abs/1512.03385)

# %%
num_classes = 10
# https://pytorch.org/vision/main/models/generated/torchvision.models.resnet50.html
model = models.resnet50()
model.fc = nn.Linear(model.fc.in_features, num_classes)
model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=10, bias=True)
# )

# %% [markdown]
# ### 3.2 Define criterion, optimizer, and scheduler

# %%
criterion = nn.CrossEntropyLoss()

# Experiment with various optimizers and schedulers.
if use_AdamW: 
    optimizer = torch.optim.AdamW(model.parameters(), lr=config['lr'], weight_decay=config['weight_decay'])
    scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=config['t_0'], eta_min=config['eta_min'])
else:
    optimizer = torch.optim.SGD(model.parameters(), lr=config['lr'], momentum=config['momentum'], weight_decay=config['weight_decay'])
    scheduler = MultiStepLR(optimizer, milestones=config['milestones'], gamma=config['gamma'])

# %% [markdown]
# ### 3.3 Define the Training Loop
# Below, we have a function that performs one training epoch. It enumerates data from the DataLoader, and on each pass of the loop does the following:
#
# * Gets a batch of training data from the DataLoader
#
# * Zeros the optimizer’s gradients
#
# * Performs an inference - that is, gets predictions from the model for an input batch
#
# * Calculates the loss for that set of predictions vs. the labels on the dataset
#
# * Calculates the backward gradients over the learning weights
#
# * Tells the optimizer to perform one learning step - that is, adjust the model’s learning weights based on the observed gradients for this batch, according to the optimization algorithm we chose
#
# * Finally, it reports the averaged epoch loss for comparison with a validation run

# %%
def train_one_epoch(epoch_index, tb_writer):
    running_loss = 0.
    train_loss = 0.
    train_acc = 0.
    num_correct = 0
    num_samples = 0

    # Here, we use enumerate(train_dataloader) instead of
    # iter(training_loader) so that we can track the batch
    # index and do some intra-epoch reporting
    for _, data in enumerate(train_dataloader):
        # Every data instance is an input + label pair
        inputs, labels = data

        # Zero your gradients for every batch!
        optimizer.zero_grad()

        # Make predictions for this batch
        outputs = model(inputs.to(device))

        # Compute the loss and its gradients
        loss = criterion(outputs, labels.to(device))
        loss.backward()

        # Adjust learning weights
        optimizer.step()

        # Gather data and report
        running_loss += loss.item()
        _, predictions = outputs.max(dim=-1)
        num_correct += (predictions == labels.to(device)).sum()
        num_samples += predictions.size(0)
        
    train_loss = running_loss/len(train_dataloader)
    train_acc = float(num_correct)/float(num_samples)

    return train_loss, train_acc

# %% [markdown]
# #### 3.4 Evaluate the Trained Model on Validation Data
# * Perform validation by examining the relative loss on a dataset that was not utilized for training.
#
# * Save a copy of the model
#
# * Utilize TensorBoard for reporting. (This necessitates launching TensorBoard from the command line and accessing it in a separate browser tab.)

# %%
# Initializing in a separate cell so we can easily add more epochs to the same run
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
writer = SummaryWriter('./eurosat_trainer_{}'.format( timestamp))
epoch_number = 0
tr_acc = 0.0
best_vloss = 1_000_000.
model_path = './model'

for epoch in range(config['epochs']):
    print('============= EPOCH {} ============='.format(epoch_number + 1))

    # Make sure gradient tracking is on, and do a pass over the data
    model.train(True)
    avg_loss, tr_acc = train_one_epoch(epoch_number, writer)

    running_vloss = 0.0
    val_acc = 0.0
    num_vcorrect = 0
    num_vsamples = 0

    # Set the model to evaluation mode, disabling dropout and using population statistics for batch normalization.
    model.eval()

    # Disable gradient computation and reduce memory consumption.
    with torch.no_grad():
        for i, vdata in enumerate(val_dataloader):
            vinputs, vlabels = vdata
            voutputs = model(vinputs.to(device))
            vloss = criterion(voutputs, vlabels.to(device))
            running_vloss += vloss
            _, vpredictions = voutputs.max(dim=-1)
            num_vcorrect += (vpredictions == vlabels.to(device)).sum()
            num_vsamples += vpredictions.size(0)

    avg_vloss = running_vloss / len(val_dataloader)
    val_acc = float(num_vcorrect)/float(num_vsamples)
    print('LOSS : train {} | valid {}'.format(round(avg_loss, 4), round(avg_vloss.item(), 4)))
    print('ACC  : train {}% | valid {}%'.format(round(tr_acc*100, 2), round(val_acc*100),2))

    # Log the running loss averaged per epoch for both training and validation
    writer.add_scalars('Training vs. Validation Loss',
                    { 'Training' : avg_loss, 'Validation' : avg_vloss },
                    epoch_number + 1)
    writer.add_scalars('Training vs. Validation Accuracy',
                    { 'Training' : tr_acc, 'Validation' : val_acc },
                    epoch_number + 1)
    writer.flush()

    # Track best performance, and save the model's state
    if avg_vloss < best_vloss:
        best_vloss = avg_vloss
        torch.save(model.state_dict(), model_path)

    epoch_number += 1
# Out:
# ============= EPOCH 1 =============
# LOSS : train 2.2305 | valid 2.2627
# ACC  : train 15.27% | valid 13%
# ============= EPOCH 2 =============
# LOSS : train 2.0988 | valid 2.1413
# ACC  : train 21.79% | valid 19%
# ============= EPOCH 3 =============
# LOSS : train 2.0863 | valid 2.1418
# ACC  : train 21.73% | valid 19%
# ============= EPOCH 4 =============
# LOSS : train 2.0467 | valid 2.4708
# ACC  : train 25.31% | valid 17%
# ============= EPOCH 5 =============
# LOSS : train 2.0351 | valid 2.0502
# ACC  : train 25.06% | valid 25%
# ============= EPOCH 6 =============
# LOSS : train 1.9934 | valid 2.0149
# ACC  : train 27.24% | valid 27%
# ============= EPOCH 7 =============
# LOSS : train 1.9973 | valid 2.0608
# ACC  : train 27.1% | valid 24%
# ============= EPOCH 8 =============
# LOSS : train 1.9842 | valid 2.0028
# ACC  : train 27.12% | valid 28%
# ============= EPOCH 9 =============
# LOSS : train 1.9575 | valid 1.9968
# ACC  : train 29.2% | valid 27%
# ============= EPOCH 10 =============
# LOSS : train 1.9394 | valid 2.0289
# ACC  : train 30.23% | valid 23%
# ============= EPOCH 11 =============
# LOSS : train 1.9176 | valid 1.9684
# ACC  : train 31.01% | valid 29%
# ============= EPOCH 12 =============
# LOSS : train 1.8879 | valid 1.8814
# ACC  : train 31.09% | valid 32%
# ============= EPOCH 13 =============
# LOSS : train 1.8348 | valid 1.85
# ACC  : train 33.17% | valid 34%
# ============= EPOCH 14 =============
# LOSS : train 1.815 | valid 1.926
# ACC  : train 33.89% | valid 30%
# ============= EPOCH 15 =============
# LOSS : train 1.8048 | valid 1.8817
# ACC  : train 34.26% | valid 30%
# ============= EPOCH 16 =============
# LOSS : train 1.8049 | valid 1.8804
# ACC  : train 33.72% | valid 33%
# ============= EPOCH 17 =============
# LOSS : train 1.78 | valid 1.7974
# ACC  : train 34.51% | valid 34%
# ============= EPOCH 18 =============
# LOSS : train 1.7361 | valid 1.7485
# ACC  : train 34.51% | valid 35%
# ============= EPOCH 19 =============
# LOSS : train 1.716 | valid 1.737
# ACC  : train 36.34% | valid 36%
# ============= EPOCH 20 =============
# LOSS : train 1.6869 | valid 1.7088
# ACC  : train 36.67% | valid 36%
# ============= EPOCH 21 =============
# LOSS : train 1.682 | valid 1.6921
# ACC  : train 37.3% | valid 36%
# ============= EPOCH 22 =============
# LOSS : train 1.6622 | valid 1.6719
# ACC  : train 38.64% | valid 38%
# ============= EPOCH 23 =============
# LOSS : train 1.6485 | valid 1.6737
# ACC  : train 38.91% | valid 39%
# ============= EPOCH 24 =============
# LOSS : train 1.6428 | valid 1.651
# ACC  : train 39.98% | valid 39%
# ============= EPOCH 25 =============
# LOSS : train 1.603 | valid 1.6233
# ACC  : train 40.84% | valid 41%
# ============= EPOCH 26 =============
# LOSS : train 1.5946 | valid 1.605
# ACC  : train 40.25% | valid 41%
# ============= EPOCH 27 =============
# LOSS : train 1.5788 | valid 1.5925
# ACC  : train 41.89% | valid 42%
# ============= EPOCH 28 =============
# LOSS : train 1.5669 | valid 1.5827
# ACC  : train 41.44% | valid 41%
# ============= EPOCH 29 =============
# LOSS : train 1.5755 | valid 1.5848
# ACC  : train 40.76% | valid 41%
# ============= EPOCH 30 =============
# LOSS : train 1.5488 | valid 1.5779
# ACC  : train 42.96% | valid 42%
# ============= EPOCH 31 =============
# LOSS : train 1.533 | valid 1.5408
# ACC  : train 44.4% | valid 45%
# ============= EPOCH 32 =============
# LOSS : train 1.5035 | valid 1.5309
# ACC  : train 45.47% | valid 45%
# ============= EPOCH 33 =============
# LOSS : train 1.5041 | valid 1.5368
# ACC  : train 45.49% | valid 43%
# ============= EPOCH 34 =============
# LOSS : train 1.4838 | valid 1.4933
# ACC  : train 45.99% | valid 47%
# ============= EPOCH 35 =============
# LOSS : train 1.4609 | valid 1.4815
# ACC  : train 47.16% | valid 47%
# ============= EPOCH 36 =============
# LOSS : train 1.4469 | valid 1.4611
# ACC  : train 48.44% | valid 48%
# ============= EPOCH 37 =============
# LOSS : train 1.4389 | valid 1.4988
# ACC  : train 48.33% | valid 46%
# ============= EPOCH 38 =============
# LOSS : train 1.4267 | valid 1.439
# ACC  : train 49.22% | valid 49%
# ============= EPOCH 39 =============
# LOSS : train 1.4165 | valid 1.4185
# ACC  : train 48.81% | valid 49%
# ============= EPOCH 40 =============
# LOSS : train 1.3925 | valid 1.3962
# ACC  : train 50.86% | valid 51%
# ============= EPOCH 41 =============
# LOSS : train 1.3807 | valid 1.4137
# ACC  : train 51.38% | valid 50%
# ============= EPOCH 42 =============
# LOSS : train 1.3661 | valid 1.3774
# ACC  : train 51.89% | valid 51%
# ============= EPOCH 43 =============
# LOSS : train 1.3471 | valid 1.3894
# ACC  : train 52.59% | valid 50%
# ============= EPOCH 44 =============
# LOSS : train 1.344 | valid 1.358
# ACC  : train 52.45% | valid 52%
# ============= EPOCH 45 =============
# LOSS : train 1.3314 | valid 1.3496
# ACC  : train 53.13% | valid 52%
# ============= EPOCH 46 =============
# LOSS : train 1.3118 | valid 1.3635
# ACC  : train 53.58% | valid 51%
# ============= EPOCH 47 =============
# LOSS : train 1.3041 | valid 1.3146
# ACC  : train 53.5% | valid 54%
# ============= EPOCH 48 =============
# LOSS : train 1.2646 | valid 1.3101
# ACC  : train 55.64% | valid 54%
# ============= EPOCH 49 =============
# LOSS : train 1.2566 | valid 1.2948
# ACC  : train 55.78% | valid 54%
# ============= EPOCH 50 =============
# LOSS : train 1.259 | valid 1.3105
# ACC  : train 55.74% | valid 54%
# ============= EPOCH 51 =============
# LOSS : train 1.2561 | valid 1.2675
# ACC  : train 55.56% | valid 55%
# ============= EPOCH 52 =============
# LOSS : train 1.2497 | valid 1.2803
# ACC  : train 55.19% | valid 54%
# ============= EPOCH 53 =============
# LOSS : train 1.2064 | valid 1.2519
# ACC  : train 57.94% | valid 56%
# ============= EPOCH 54 =============
# LOSS : train 1.2043 | valid 1.2184
# ACC  : train 57.7% | valid 57%
# ============= EPOCH 55 =============
# LOSS : train 1.1808 | valid 1.2043
# ACC  : train 58.5% | valid 57%
# ============= EPOCH 56 =============
# LOSS : train 1.1693 | valid 1.2136
# ACC  : train 59.03% | valid 56%
# ============= EPOCH 57 =============
# LOSS : train 1.1478 | valid 1.2137
# ACC  : train 59.12% | valid 56%
# ============= EPOCH 58 =============
# LOSS : train 1.1372 | valid 1.5987
# ACC  : train 59.4% | valid 46%
# ============= EPOCH 59 =============
# LOSS : train 1.1197 | valid 1.1863
# ACC  : train 60.1% | valid 57%
# ============= EPOCH 60 =============
# LOSS : train 1.116 | valid 1.1242
# ACC  : train 59.47% | valid 59%
# ============= EPOCH 61 =============
# LOSS : train 1.0804 | valid 1.0975
# ACC  : train 60.95% | valid 60%
# ============= EPOCH 62 =============
# LOSS : train 1.0717 | valid 1.1559
# ACC  : train 61.11% | valid 57%
# ============= EPOCH 63 =============
# LOSS : train 1.0811 | valid 1.1289
# ACC  : train 60.21% | valid 59%
# ============= EPOCH 64 =============
# LOSS : train 1.0745 | valid 1.1346
# ACC  : train 61.28% | valid 58%
# ============= EPOCH 65 =============
# LOSS : train 1.0537 | valid 1.1002
# ACC  : train 61.17% | valid 59%
# ============= EPOCH 66 =============
# LOSS : train 1.0332 | valid 1.0924
# ACC  : train 62.76% | valid 60%
# ============= EPOCH 67 =============
# LOSS : train 1.0341 | valid 1.0648
# ACC  : train 62.45% | valid 60%
# ============= EPOCH 68 =============
# LOSS : train 1.0246 | valid 1.066
# ACC  : train 62.35% | valid 61%
# ============= EPOCH 69 =============
# LOSS : train 1.0077 | valid 1.0743
# ACC  : train 63.48% | valid 61%
# ============= EPOCH 70 =============
# LOSS : train 0.984 | valid 1.0872
# ACC  : train 63.99% | valid 59%
# ============= EPOCH 71 =============
# LOSS : train 1.0152 | valid 1.0572
# ACC  : train 63.97% | valid 62%
# ============= EPOCH 72 =============
# LOSS : train 0.9916 | valid 1.029
# ACC  : train 63.33% | valid 63%
# ============= EPOCH 73 =============
# LOSS : train 0.9661 | valid 1.0279
# ACC  : train 65.31% | valid 62%
# ============= EPOCH 74 =============
# LOSS : train 0.9688 | valid 1.1015
# ACC  : train 64.42% | valid 58%
# ============= EPOCH 75 =============
# LOSS : train 0.9853 | valid 1.0657
# ACC  : train 63.58% | valid 61%
# ============= EPOCH 76 =============
# LOSS : train 0.9757 | valid 1.0284
# ACC  : train 64.24% | valid 62%
# ============= EPOCH 77 =============
# LOSS : train 0.959 | valid 1.1137
# ACC  : train 64.67% | valid 59%
# ============= EPOCH 78 =============
# LOSS : train 0.9522 | valid 0.9864
# ACC  : train 65.31% | valid 64%
# ============= EPOCH 79 =============
# LOSS : train 0.9379 | valid 1.1571
# ACC  : train 65.37% | valid 58%
# ============= EPOCH 80 =============
# LOSS : train 0.9276 | valid 0.9917
# ACC  : train 66.13% | valid 63%
# ============= EPOCH 81 =============
# LOSS : train 0.9182 | valid 1.1203
# ACC  : train 66.23% | valid 59%
# ============= EPOCH 82 =============
# LOSS : train 0.9019 | valid 1.3092
# ACC  : train 66.98% | valid 56%
# ============= EPOCH 83 =============
# LOSS : train 0.8884 | valid 0.9491
# ACC  : train 68.11% | valid 66%
# ============= EPOCH 84 =============
# LOSS : train 0.8859 | valid 1.0175
# ACC  : train 67.55% | valid 63%
# ============= EPOCH 85 =============
# LOSS : train 0.8825 | valid 0.9476
# ACC  : train 67.67% | valid 65%
# ============= EPOCH 86 =============
# LOSS : train 0.8796 | valid 0.9776
# ACC  : train 67.74% | valid 64%
# ============= EPOCH 87 =============
# LOSS : train 0.8723 | valid 0.9432
# ACC  : train 67.82% | valid 66%
# ============= EPOCH 88 =============
# LOSS : train 0.8603 | valid 0.9269
# ACC  : train 68.72% | valid 66%
# ============= EPOCH 89 =============
# LOSS : train 0.844 | valid 0.9319
# ACC  : train 69.69% | valid 66%
# ============= EPOCH 90 =============
# LOSS : train 0.8486 | valid 1.0749
# ACC  : train 68.46% | valid 62%
# ============= EPOCH 91 =============
# LOSS : train 0.8556 | valid 1.0084
# ACC  : train 69.09% | valid 63%
# ============= EPOCH 92 =============
# LOSS : train 0.8393 | valid 0.9652
# ACC  : train 69.47% | valid 65%
# ============= EPOCH 93 =============
# LOSS : train 0.847 | valid 0.9175
# ACC  : train 69.36% | valid 67%
# ============= EPOCH 94 =============
# LOSS : train 0.8597 | valid 1.0183
# ACC  : train 68.35% | valid 63%
# ============= EPOCH 95 =============
# LOSS : train 0.8209 | valid 0.8996
# ACC  : train 69.59% | valid 67%
# ============= EPOCH 96 =============
# LOSS : train 0.7976 | valid 0.9087
# ACC  : train 70.53% | valid 66%
# ============= EPOCH 97 =============
# LOSS : train 0.7946 | valid 1.0695
# ACC  : train 71.28% | valid 63%
# ============= EPOCH 98 =============
# LOSS : train 0.788 | valid 0.9205
# ACC  : train 71.58% | valid 67%
# ============= EPOCH 99 =============
# LOSS : train 0.7899 | valid 0.8768
# ACC  : train 71.89% | valid 68%
# ============= EPOCH 100 =============
# LOSS : train 0.7918 | valid 0.8681
# ACC  : train 71.3% | valid 69%

# %% [markdown]
# ## 4. Model evaluation on Test Data

# %% [markdown]
# ### 4.1 Load the model with the lowest validation loss.

# %%
model = models.resnet50()
model.fc = nn.Linear(model.fc.in_features, num_classes)
model.load_state_dict(torch.load(model_path))
model.to(device)
model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=10, bias=True)
# )

# %% [markdown]
# ### 4.2 Evaluate the top-performing model on the Test Data.

# %%
running_tloss = 0.
test_acc = 0.
num_tcorrect = 0
num_tsamples = 0
with torch.no_grad():
    for _, tdata in enumerate(test_dataloader):
        tinputs, tlabels = tdata
        toutputs = model(tinputs.to(device))
        tloss = criterion(toutputs, tlabels.to(device))
        running_tloss += tloss
        _, tpredictions = toutputs.max(dim=-1)
        num_tcorrect += (tpredictions == tlabels.to(device)).sum()
        num_tsamples += tpredictions.size(0)

avg_tloss = running_tloss/len(test_dataloader)
test_acc = float(num_tcorrect)/float(num_tsamples)
print('LOSS : train {} | valid {} | test {}'.format(round(avg_tloss.item(), 4), round(avg_vloss.item(), 4), round(avg_tloss.item(), 4)))
print('ACC  : train {}% | valid {}%  | test {}%'.format(round(tr_acc*100, 2), round(val_acc*100),2), round(test_acc*100,2))
# Out:
# LOSS : train 0.9187 | valid 0.8681 | test 0.9187
# ACC  : train 71.3% | valid 69%  | test 2% 67.89

# %% [markdown]
# ### 4.3 Predict the label of an image from the Test Data and visualize the image.

# %%
# Random select an index
random_index = random.randrange(len(tinputs)) # 

# Transform the image from the final batch of Test Data using the chosen index.
random_image = tinputs[random_index].numpy().transpose((1, 2, 0))
random_image = std * random_image + mean
random_image = np.clip(random_image, 0, 1)

# Display the image along with its predicted and actual labels.
print("Image", random_index, "'s label :", tlabels[random_index].item(), classes[tlabels[random_index].item()], "| Predicted label :", tpredictions[random_index].detach().cpu().item(), classes[tpredictions[random_index].detach().cpu().item()])
plt.imshow(random_image)
# Out:
# Image 3 's label : 1 Forest | Predicted label : 1 Forest
