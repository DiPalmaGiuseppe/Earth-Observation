# %% [markdown]
# # Earth Observation - Land Classification on EuroSAT dataset
#
# * EuroSAT is a large-scale land use and land cover classification dataset derived from multispectral Sentinel-2 satellite imagery covering European continent.
#
# * EuroSAT is composed of 27,000 georeferenced image patches (64 x 64 pixels) - each patch comprises 13 spectral bands (optical through to shortwave infrared ) resampled to 10m spatila resolution and labelled with one of 10 distinct land cover classes: AnnualCrop, Forest, HerbaceousVegetation, Highway, Industrial, Pasture, PermanentCrop, Residential, River, SeaLake.
#
# * Full details including links to journal papers and download instructions may be found here: https://github.com/phelber/eurosat.
#
# ![alt text](https://github.com/phelber/EuroSAT/blob/master/eurosat_overview_small.jpg?raw=true)

# %% [markdown]
# ##  1. Setup Notebook Environment

# %% [markdown]
# ### 1.1 Import all required packages.

# %%
import os
import ssl
import torch
import random
import numpy as np
import torch.nn as nn
from datetime import datetime
import matplotlib.pyplot as plt
from torchvision import models, transforms
from torchvision.datasets import EuroSAT
from torch.utils.tensorboard.writer import SummaryWriter
from torch.optim.lr_scheduler import MultiStepLR, CosineAnnealingWarmRestarts

# %% [markdown]
# ### 1.2 Configure settings for the corresponding optimizers and schedulers.

# %%
model_path = './model'
use_AdamW = False # Flag utilized for switching between AdamW and SGD optimizer.

if use_AdamW:
  config = {'train_test_split':0.1, # train test split ratio
            'tr_val_split':0.2, # train validation split ratio
            'seed':42, # random seed
            'mini_batch_size':128,
            'epochs':20,
            
            # Settings for the optimizer AdamW
            'lr':1e-3, # learning rate
            'weight_decay':5e-4,

            # Settings for the lr_scheduler CosineAnnealingWarmRestarts
            't_0':5, # Number of iterations for the first restart.
            'eta_min':1e-5, # Minimum learning rate
          }
else:
  config = {'train_test_split':0.1, # train test split ratio
            'tr_val_split':0.2, # train validation split ratio
            'seed':42, # random seed
            'mini_batch_size':128,
            'epochs':100,

            # Settings for the optimizer SGD
            'lr':1e-4, # learning rate
            'weight_decay':5e-4,  
            'momentum':0.9,

            # Settings for the lr_scheduler MultiStepLR
            'milestones':[50,75,90], # List of epoch indices.
            'gamma':0.2, # Multiplicative factor of learning rate decay.
          }

# %% [markdown]
# ### 1.3 Define a function to set a random seed for reproducibility assurance:
# * Manage sources of randomness that may lead to varying behaviors in multiple executions of your application.

# %%
def set_random_seed(seed=42):
    random.seed(seed) # set python seed
    np.random.seed(seed) # seed the global NumPy random number generator(RNG)
    torch.manual_seed(seed) # seed the RNG for all devices(both CPU and CUDA) 

set_random_seed(seed=config['seed'])

# %% [markdown]
# ### 1.4 Tracks the active GPU and allocates all new CUDA tensors on that device by default.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device = torch.device(device)

# %% [markdown]
# ## 2. Data Preparation:

# %% [markdown]
# ### 2.1 Preparing the dataset:

# %%
# Transform pipeline
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])])

# Dataset download
ssl._create_default_https_context = ssl._create_unverified_context # Turn off the ssl verification.
dataset_path = "../../"
dataset = EuroSAT(root=dataset_path, transform=transform, download=True)

# Train/Test split
n = int(len(dataset) * (1 - config['train_test_split']))
eurosat_train, eurosat_test = torch.utils.data.random_split(dataset, [n, len(dataset) - n])

# %% [markdown]
# ### 2.2 Visualize Training Data

# %%
# Randomly select an image from the Training Data for visualization and print its corresponding label.
classes = ['AnnualCrop', 'Forest', 'HerbaceousVegetation', 'Highway', 'Industrial', 'Pasture', 'PermanentCrop', 'Residential', 'River', 'SeaLake']
random_index = random.randrange(len(eurosat_train)) # random select an index
random_image = eurosat_train[random_index][0].numpy().transpose((1, 2, 0))
mean = np.array([0.485, 0.456, 0.406])
std = np.array([0.229, 0.224, 0.225])
random_image = std * random_image + mean
random_image = np.clip(random_image, 0, 1)
print("Image", random_index, "'s label :", eurosat_train[random_index][1], classes[eurosat_train[random_index][1]])
plt.imshow(random_image)
# Out:
# Image 20952 's label : 6 PermanentCrop

# %% [markdown]
# ### 2.3 Instantiate PyTorch data loader that feeds the image tensors to our neural network

# %%
# Tr/Val split
n = int(len(eurosat_train) * config['tr_val_split'])
eurosat_tr, eurosat_val = torch.utils.data.random_split(eurosat_train, [n, len(eurosat_train) - n])

# instantiate data loaders
train_dataloader = torch.utils.data.DataLoader(eurosat_tr, batch_size=config['mini_batch_size'], shuffle=True)
val_dataloader = torch.utils.data.DataLoader(eurosat_val, batch_size=config['mini_batch_size'], shuffle=True)
test_dataloader = torch.utils.data.DataLoader(eurosat_test, batch_size=config['mini_batch_size'], shuffle=True)

# %% [markdown]
# ## 3. Model Training

# %% [markdown]
# ### 3.1 Create a ResNet-50 model using torchvision

# %%
num_classes = 10
# https://pytorch.org/vision/main/models/generated/torchvision.models.resnet50.html
model = models.resnet50(weights='DEFAULT')
model.fc = nn.Linear(model.fc.in_features, num_classes)
model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=10, bias=True)
# )

# %% [markdown]
# ### 3.2 Define criterion, optimizer, and scheduler

# %%
criterion = nn.CrossEntropyLoss()

# Experiment with various optimizers and schedulers.
if use_AdamW: 
    optimizer = torch.optim.AdamW(model.parameters(), lr=config['lr'], weight_decay=config['weight_decay'])
    scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=config['t_0'], eta_min=config['eta_min'])
else:
    optimizer = torch.optim.SGD(model.parameters(), lr=config['lr'], momentum=config['momentum'], weight_decay=config['weight_decay'])
    scheduler = MultiStepLR(optimizer, milestones=config['milestones'], gamma=config['gamma'])

# %% [markdown]
# ### 3.3 Define the Training Loop
# Below, we have a function that performs one training epoch. It enumerates data from the DataLoader, and on each pass of the loop does the following:
#
# * Gets a batch of training data from the DataLoader
#
# * Zeros the optimizer’s gradients
#
# * Performs an inference - that is, gets predictions from the model for an input batch
#
# * Calculates the loss for that set of predictions vs. the labels on the dataset
#
# * Calculates the backward gradients over the learning weights
#
# * Tells the optimizer to perform one learning step - that is, adjust the model’s learning weights based on the observed gradients for this batch, according to the optimization algorithm we chose
#
# * Finally, it reports the averaged epoch loss for comparison with a validation run

# %%
def train_one_epoch(epoch_index, tb_writer):
    running_loss = 0.
    train_loss = 0.
    train_acc = 0.
    num_correct = 0
    num_samples = 0

    # Here, we use enumerate(train_dataloader) instead of
    # iter(training_loader) so that we can track the batch
    # index and do some intra-epoch reporting
    for _, data in enumerate(train_dataloader):
        # Every data instance is an input + label pair
        inputs, labels = data

        # Zero your gradients for every batch!
        optimizer.zero_grad()

        # Make predictions for this batch
        outputs = model(inputs.to(device))

        # Compute the loss and its gradients
        loss = criterion(outputs, labels.to(device))
        loss.backward()

        # Adjust learning weights
        optimizer.step()

        # Gather data and report
        running_loss += loss.item()
        _, predictions = outputs.max(dim=-1)
        num_correct += (predictions == labels.to(device)).sum()
        num_samples += predictions.size(0)
        
    train_loss = running_loss/len(train_dataloader)
    train_acc = float(num_correct)/float(num_samples)

    return train_loss, train_acc

# %% [markdown]
# #### 3.4 Evaluate the Trained Model on Validation Data
# * Perform validation by examining the relative loss on a dataset that was not utilized for training.
#
# * Save a copy of the model
#
# * Utilize TensorBoard for reporting. (This necessitates launching TensorBoard from the command line and accessing it in a separate browser tab.)

# %%
# Initializing in a separate cell so we can easily add more epochs to the same run

directory_path="./model"
if not os.path.exists(directory_path):
    os.makedirs(directory_path)

timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
writer = SummaryWriter('./eurosat_trainer_{}'.format(timestamp))
epoch_number = 0
tr_acc = 0.0
best_vloss = 1_000_000.

for epoch in range(config['epochs']):
    print('============= EPOCH {} ============='.format(epoch_number + 1))

    # Make sure gradient tracking is on, and do a pass over the data
    model.train(True)
    avg_loss, tr_acc = train_one_epoch(epoch_number, writer)

    running_vloss = 0.0
    val_acc = 0.0
    num_vcorrect = 0
    num_vsamples = 0

    # Set the model to evaluation mode, disabling dropout and using population statistics for batch normalization.
    model.eval()

    # Disable gradient computation and reduce memory consumption.
    with torch.no_grad():
        for i, vdata in enumerate(val_dataloader):
            vinputs, vlabels = vdata
            voutputs = model(vinputs.to(device))
            vloss = criterion(voutputs, vlabels.to(device))
            running_vloss += vloss
            _, vpredictions = voutputs.max(dim=-1)
            num_vcorrect += (vpredictions == vlabels.to(device)).sum()
            num_vsamples += vpredictions.size(0)

    avg_vloss = running_vloss / len(val_dataloader)
    val_acc = float(num_vcorrect)/float(num_vsamples)
    print('LOSS : train {} | valid {}'.format(round(avg_loss, 4), round(avg_vloss.item(), 4)))
    print('ACC  : train {}% | valid {}%'.format(round(tr_acc*100, 2), round(val_acc*100),2))

    # Log the running loss averaged per epoch for both training and validation
    writer.add_scalars('Training vs. Validation Loss',
                    { 'Training' : avg_loss, 'Validation' : avg_vloss },
                    epoch_number + 1)
    writer.add_scalars('Training vs. Validation Accuracy',
                    { 'Training' : tr_acc, 'Validation' : val_acc },
                    epoch_number + 1)
    writer.flush()

    # Track best performance, and save the model's state
    if avg_vloss < best_vloss:
        best_vloss = avg_vloss
        torch.save(model.state_dict(), model_path)

    epoch_number += 1
# Out:
# ============= EPOCH 1 =============
# LOSS : train 2.3022 | valid 2.277
# ACC  : train 13.07% | valid 15%
# ============= EPOCH 2 =============
# LOSS : train 2.251 | valid 2.2293
# ACC  : train 17.72% | valid 21%
# ============= EPOCH 3 =============
# LOSS : train 2.1903 | valid 2.1676
# ACC  : train 25.62% | valid 29%
# ============= EPOCH 4 =============
# LOSS : train 2.1161 | valid 2.0928
# ACC  : train 33.31% | valid 38%
# ============= EPOCH 5 =============
# LOSS : train 2.0221 | valid 1.9988
# ACC  : train 42.67% | valid 45%
# ============= EPOCH 6 =============
# LOSS : train 1.9104 | valid 1.8862
# ACC  : train 50.78% | valid 52%
# ============= EPOCH 7 =============
# LOSS : train 1.8002 | valid 1.7931
# ACC  : train 56.6% | valid 57%
# ============= EPOCH 8 =============
# LOSS : train 1.684 | valid 1.6683
# ACC  : train 61.28% | valid 61%
# ============= EPOCH 9 =============
# LOSS : train 1.556 | valid 1.5594
# ACC  : train 64.88% | valid 65%
# ============= EPOCH 10 =============
# LOSS : train 1.4376 | valid 1.4434
# ACC  : train 68.83% | valid 67%
# ============= EPOCH 11 =============
# LOSS : train 1.3233 | valid 1.3419
# ACC  : train 70.97% | valid 70%
# ============= EPOCH 12 =============
# LOSS : train 1.2138 | valid 1.2412
# ACC  : train 73.87% | valid 71%
# ============= EPOCH 13 =============
# LOSS : train 1.1113 | valid 1.1475
# ACC  : train 75.84% | valid 73%
# ============= EPOCH 14 =============
# LOSS : train 1.0155 | valid 1.0745
# ACC  : train 78.56% | valid 75%
# ============= EPOCH 15 =============
# LOSS : train 0.938 | valid 0.995
# ACC  : train 80.02% | valid 77%
# ============= EPOCH 16 =============
# LOSS : train 0.8687 | valid 0.9293
# ACC  : train 81.3% | valid 79%
# ============= EPOCH 17 =============
# LOSS : train 0.8004 | valid 0.8686
# ACC  : train 83.11% | valid 79%
# ============= EPOCH 18 =============
# LOSS : train 0.7332 | valid 0.8145
# ACC  : train 84.59% | valid 81%
# ============= EPOCH 19 =============
# LOSS : train 0.6812 | valid 0.7688
# ACC  : train 85.45% | valid 81%
# ============= EPOCH 20 =============
# LOSS : train 0.6385 | valid 0.7321
# ACC  : train 86.54% | valid 82%
# ============= EPOCH 21 =============
# LOSS : train 0.5883 | valid 0.6897
# ACC  : train 87.39% | valid 83%
# ============= EPOCH 22 =============
# LOSS : train 0.5515 | valid 0.6548
# ACC  : train 88.15% | valid 84%
# ============= EPOCH 23 =============
# LOSS : train 0.5095 | valid 0.6303
# ACC  : train 88.72% | valid 84%
# ============= EPOCH 24 =============
# LOSS : train 0.4943 | valid 0.5999
# ACC  : train 88.7% | valid 85%
# ============= EPOCH 25 =============
# LOSS : train 0.4503 | valid 0.5733
# ACC  : train 90.1% | valid 85%
# ============= EPOCH 26 =============
# LOSS : train 0.422 | valid 0.5545
# ACC  : train 91.03% | valid 86%
# ============= EPOCH 27 =============
# LOSS : train 0.4112 | valid 0.5342
# ACC  : train 91.03% | valid 86%
# ============= EPOCH 28 =============
# LOSS : train 0.3809 | valid 0.5137
# ACC  : train 91.89% | valid 86%
# ============= EPOCH 29 =============
# LOSS : train 0.3653 | valid 0.4996
# ACC  : train 91.81% | valid 87%
# ============= EPOCH 30 =============
# LOSS : train 0.3426 | valid 0.4847
# ACC  : train 92.59% | valid 87%
# ============= EPOCH 31 =============
# LOSS : train 0.3275 | valid 0.4723
# ACC  : train 92.84% | valid 87%
# ============= EPOCH 32 =============
# LOSS : train 0.3128 | valid 0.4579
# ACC  : train 93.31% | valid 88%
# ============= EPOCH 33 =============
# LOSS : train 0.299 | valid 0.4455
# ACC  : train 93.31% | valid 88%
# ============= EPOCH 34 =============
# LOSS : train 0.2881 | valid 0.4366
# ACC  : train 93.68% | valid 88%
# ============= EPOCH 35 =============
# LOSS : train 0.2842 | valid 0.4266
# ACC  : train 93.42% | valid 88%
# ============= EPOCH 36 =============
# LOSS : train 0.2567 | valid 0.4134
# ACC  : train 94.77% | valid 88%
# ============= EPOCH 37 =============
# LOSS : train 0.2475 | valid 0.4062
# ACC  : train 94.71% | valid 88%
# ============= EPOCH 38 =============
# LOSS : train 0.2363 | valid 0.3972
# ACC  : train 94.88% | valid 89%
# ============= EPOCH 39 =============
# LOSS : train 0.2373 | valid 0.3911
# ACC  : train 94.69% | valid 89%
# ============= EPOCH 40 =============
# LOSS : train 0.2272 | valid 0.3863
# ACC  : train 94.94% | valid 89%
# ============= EPOCH 41 =============
# LOSS : train 0.2135 | valid 0.3771
# ACC  : train 95.33% | valid 89%
# ============= EPOCH 42 =============
# LOSS : train 0.1995 | valid 0.3725
# ACC  : train 95.8% | valid 89%
# ============= EPOCH 43 =============
# LOSS : train 0.1994 | valid 0.3657
# ACC  : train 95.76% | valid 89%
# ============= EPOCH 44 =============
# LOSS : train 0.1886 | valid 0.3603
# ACC  : train 95.82% | valid 89%
# ============= EPOCH 45 =============
# LOSS : train 0.186 | valid 0.3593
# ACC  : train 95.76% | valid 89%
# ============= EPOCH 46 =============
# LOSS : train 0.1731 | valid 0.3503
# ACC  : train 96.5% | valid 90%
# ============= EPOCH 47 =============
# LOSS : train 0.1683 | valid 0.3464
# ACC  : train 96.71% | valid 90%
# ============= EPOCH 48 =============
# LOSS : train 0.1581 | valid 0.3403
# ACC  : train 96.73% | valid 90%
# ============= EPOCH 49 =============
# LOSS : train 0.156 | valid 0.3392
# ACC  : train 96.85% | valid 90%
# ============= EPOCH 50 =============
# LOSS : train 0.1544 | valid 0.3323
# ACC  : train 96.81% | valid 90%
# ============= EPOCH 51 =============
# LOSS : train 0.1452 | valid 0.327
# ACC  : train 96.95% | valid 90%
# ============= EPOCH 52 =============
# LOSS : train 0.1448 | valid 0.3258
# ACC  : train 97.06% | valid 90%
# ============= EPOCH 53 =============
# LOSS : train 0.1359 | valid 0.3231
# ACC  : train 97.47% | valid 90%
# ============= EPOCH 54 =============
# LOSS : train 0.1365 | valid 0.3178
# ACC  : train 97.3% | valid 90%
# ============= EPOCH 55 =============
# LOSS : train 0.1324 | valid 0.3165
# ACC  : train 97.43% | valid 90%
# ============= EPOCH 56 =============
# LOSS : train 0.1308 | valid 0.3144
# ACC  : train 97.49% | valid 90%
# ============= EPOCH 57 =============
# LOSS : train 0.1221 | valid 0.3126
# ACC  : train 97.65% | valid 90%
# ============= EPOCH 58 =============
# LOSS : train 0.1189 | valid 0.3108
# ACC  : train 97.76% | valid 91%
# ============= EPOCH 59 =============
# LOSS : train 0.111 | valid 0.3056
# ACC  : train 97.96% | valid 91%
# ============= EPOCH 60 =============
# LOSS : train 0.1147 | valid 0.3049
# ACC  : train 97.94% | valid 91%
# ============= EPOCH 61 =============
# LOSS : train 0.1041 | valid 0.3002
# ACC  : train 97.98% | valid 91%
# ============= EPOCH 62 =============
# LOSS : train 0.1052 | valid 0.3007
# ACC  : train 98.15% | valid 91%
# ============= EPOCH 63 =============
# LOSS : train 0.1084 | valid 0.2982
# ACC  : train 97.98% | valid 91%
# ============= EPOCH 64 =============
# LOSS : train 0.1114 | valid 0.2955
# ACC  : train 97.92% | valid 91%
# ============= EPOCH 65 =============
# LOSS : train 0.0983 | valid 0.2933
# ACC  : train 98.23% | valid 91%
# ============= EPOCH 66 =============
# LOSS : train 0.0915 | valid 0.2915
# ACC  : train 98.44% | valid 91%
# ============= EPOCH 67 =============
# LOSS : train 0.0924 | valid 0.2911
# ACC  : train 98.5% | valid 91%
# ============= EPOCH 68 =============
# LOSS : train 0.0919 | valid 0.2899
# ACC  : train 98.42% | valid 91%
# ============= EPOCH 69 =============
# LOSS : train 0.0891 | valid 0.2874
# ACC  : train 98.31% | valid 91%
# ============= EPOCH 70 =============
# LOSS : train 0.0808 | valid 0.2856
# ACC  : train 98.77% | valid 91%
# ============= EPOCH 71 =============
# LOSS : train 0.0903 | valid 0.2848
# ACC  : train 98.25% | valid 91%
# ============= EPOCH 72 =============
# LOSS : train 0.0848 | valid 0.2822
# ACC  : train 98.56% | valid 91%
# ============= EPOCH 73 =============
# LOSS : train 0.0798 | valid 0.2803
# ACC  : train 98.68% | valid 91%
# ============= EPOCH 74 =============
# LOSS : train 0.0736 | valid 0.2785
# ACC  : train 98.87% | valid 91%
# ============= EPOCH 75 =============
# LOSS : train 0.077 | valid 0.2769
# ACC  : train 98.91% | valid 91%
# ============= EPOCH 76 =============
# LOSS : train 0.0789 | valid 0.2753
# ACC  : train 98.66% | valid 91%
# ============= EPOCH 77 =============
# LOSS : train 0.0652 | valid 0.2766
# ACC  : train 99.18% | valid 91%
# ============= EPOCH 78 =============
# LOSS : train 0.0762 | valid 0.2756
# ACC  : train 98.54% | valid 91%
# ============= EPOCH 79 =============
# LOSS : train 0.0731 | valid 0.2723
# ACC  : train 98.81% | valid 92%
# ============= EPOCH 80 =============
# LOSS : train 0.073 | valid 0.2714
# ACC  : train 98.89% | valid 92%
# ============= EPOCH 81 =============
# LOSS : train 0.0662 | valid 0.2714
# ACC  : train 98.87% | valid 92%
# ============= EPOCH 82 =============
# LOSS : train 0.0649 | valid 0.2692
# ACC  : train 99.01% | valid 92%
# ============= EPOCH 83 =============
# LOSS : train 0.0588 | valid 0.2682
# ACC  : train 99.28% | valid 92%
# ============= EPOCH 84 =============
# LOSS : train 0.0614 | valid 0.2672
# ACC  : train 99.07% | valid 92%
# ============= EPOCH 85 =============
# LOSS : train 0.06 | valid 0.2655
# ACC  : train 99.28% | valid 92%
# ============= EPOCH 86 =============
# LOSS : train 0.0609 | valid 0.2675
# ACC  : train 98.97% | valid 92%
# ============= EPOCH 87 =============
# LOSS : train 0.0612 | valid 0.2648
# ACC  : train 98.87% | valid 92%
# ============= EPOCH 88 =============
# LOSS : train 0.0569 | valid 0.265
# ACC  : train 99.26% | valid 92%
# ============= EPOCH 89 =============
# LOSS : train 0.0537 | valid 0.2623
# ACC  : train 99.28% | valid 92%
# ============= EPOCH 90 =============
# LOSS : train 0.0551 | valid 0.2628
# ACC  : train 99.34% | valid 92%
# ============= EPOCH 91 =============
# LOSS : train 0.0556 | valid 0.2634
# ACC  : train 99.24% | valid 92%
# ============= EPOCH 92 =============
# LOSS : train 0.0505 | valid 0.2608
# ACC  : train 99.34% | valid 92%
# ============= EPOCH 93 =============
# LOSS : train 0.0531 | valid 0.261
# ACC  : train 99.24% | valid 92%
# ============= EPOCH 94 =============
# LOSS : train 0.0552 | valid 0.2605
# ACC  : train 99.09% | valid 92%
# ============= EPOCH 95 =============
# LOSS : train 0.0551 | valid 0.2625
# ACC  : train 99.14% | valid 92%
# ============= EPOCH 96 =============
# LOSS : train 0.049 | valid 0.2586
# ACC  : train 99.4% | valid 92%
# ============= EPOCH 97 =============
# LOSS : train 0.0482 | valid 0.2571
# ACC  : train 99.36% | valid 92%
# ============= EPOCH 98 =============
# LOSS : train 0.0503 | valid 0.2572
# ACC  : train 99.34% | valid 92%
# ============= EPOCH 99 =============
# LOSS : train 0.0457 | valid 0.2564
# ACC  : train 99.26% | valid 92%
# ============= EPOCH 100 =============
# LOSS : train 0.0477 | valid 0.2543
# ACC  : train 99.18% | valid 92%

# %% [markdown]
# ## 4. Model evaluation on Test Data

# %% [markdown]
# ### 4.1 Load the model with the lowest validation loss.

# %%
model = models.resnet50()
model.fc = nn.Linear(model.fc.in_features, num_classes)
model.load_state_dict(torch.load(model_path))
model.to(device)
model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=10, bias=True)
# )

# %% [markdown]
# ### 4.2 Evaluate the top-performing model on the Test Data.

# %%
running_tloss = 0.
test_acc = 0.
num_tcorrect = 0
num_tsamples = 0
with torch.no_grad():
    for _, tdata in enumerate(test_dataloader):
        tinputs, tlabels = tdata
        toutputs = model(tinputs.to(device))
        tloss = criterion(toutputs, tlabels.to(device))
        running_tloss += tloss
        _, tpredictions = toutputs.max(dim=-1)
        num_tcorrect += (tpredictions == tlabels.to(device)).sum()
        num_tsamples += tpredictions.size(0)

avg_tloss = running_tloss/len(test_dataloader)
test_acc = float(num_tcorrect)/float(num_tsamples)
print(f'Loss: {round(avg_tloss.item(),4)}')
print(f'Accuracy: {round(test_acc*100,2)}')
# Out:
# Loss: 0.2729
# Accuracy: 91.96

# %% [markdown]
# ### 4.3 Predict the label of an image from the Test Data and visualize the image.

# %%
# Random select an index
random_index = random.randrange(len(tinputs)) # 

# Transform the image from the final batch of Test Data using the chosen index.
random_image = tinputs[random_index].numpy().transpose((1, 2, 0))
random_image = std * random_image + mean
random_image = np.clip(random_image, 0, 1)

# Display the image along with its predicted and actual labels.
print("Image", random_index, "'s label :", tlabels[random_index].item(), classes[tlabels[random_index].item()], "| Predicted label :", tpredictions[random_index].detach().cpu().item(), classes[tpredictions[random_index].detach().cpu().item()])
plt.imshow(random_image)
# Out:
# Image 1 's label : 6 PermanentCrop | Predicted label : 2 HerbaceousVegetation
